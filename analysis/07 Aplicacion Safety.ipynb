# %%
import pandas as pd
import os

import biogeme.database as db
import biogeme.biogeme as bio
import biogeme.distributions as dist
import biogeme.models as models
import biogeme.results as res

# %%
data = pd.read_csv('./../00 Insumos/02 Stgo/data_aplicacion.csv')

# %%
data['transport'] = 0
data['gender'] = 0
data['choice'] = 1
database = db.Database("database",data)
from headers import *

# %%
B_mean_h = Beta('LLF: mean_h', 0, -100, 100, 0)
B_mean_l = Beta('LLF: mean_l', 0, -100, 100, 0)
B_mean_s = Beta('LLF: mean_s', 0, -100, 100, 0)
B_mean_bn = Beta('LLF: mean_bn', 0, -100, 100, 1)  # NS
B_stdev_h = Beta('LLF: stdev_h', 0, -100, 100, 0)
B_stdev_l = Beta('LLF: stdev_l', 0, -100, 100, 0)
B_stdev_s = Beta('LLF: stdev_s', 0, -100, 100, 0)
B_stdev_bn = Beta('LLF: stdev_bn', 0, -100, 100, 1)  # NS

B_edges = Beta('LLF: edges', 0, -100, 100, 0)
B_blobs = Beta('LLF: blobs', 0, -100, 100, 1)


B_Bicyclist_N = Beta('HLF N: Bicyclist', 0, -100, 100, 1) 
B_Building_N = Beta('HLF N: Building', 0, -100, 100, 0)
B_Car_N = Beta('HLF N: Car', 0, -100, 100, 0) 
B_Fence_N = Beta('HLF N: Fence', 0, -100, 100, 0) 
B_Pavement_N = Beta('HLF N: Pavement', 0, -100, 100, 1)  # NS 0
B_Pedestrian_N = Beta('HLF N: Pedestrian', 0, -100, 100, 1)
B_Pole_N = Beta('HLF N: Pole', 0, -100, 100, 0) 
B_Road_N = Beta('HLF N: Road', 0, -100, 100, 1)  # NS 0
B_SignSymbol_N = Beta('HLF N: SignSymbol', 0, -100, 100, 0) 
B_Sky_N = Beta('HLF N: Sky', 0, -100, 100, 0)
B_Tree_N = Beta('HLF N: Tree', 0, -100, 100, 0)

B_Bicyclist_S = Beta('HLF S: Bicyclist', 0, -100, 100, 1) 
B_Building_S = Beta('HLF S: Building', 0, -100, 100, 1) 
B_Car_S = Beta('HLF S: Car', 0, -100, 100, 1)
B_Fence_S = Beta('HLF S: Fence', 0, -100, 100, 1) 
B_Pavement_S = Beta('HLF S: Pavement', 0, -100, 100, 1)
B_Pedestrian_S = Beta('HLF S: Pedestrian', 0, -100, 100, 1)
B_Pole_S = Beta('HLF S: Pole', 0, -100, 100, 0)
B_Road_S = Beta('HLF S: Road', 0, -100, 100, 0)
B_SignSymbol_S = Beta('HLF S: SignSymbol', 0, -100, 100, 1)
B_Sky_S = Beta('HLF S: Sky', 0, -100, 100, 1) # NS 0 
B_Tree_S = Beta('HLF S: Tree', 0, -100, 100, 0) 


D_bench = Beta('OD: bench', 0, -100, 100, 1)
D_boat = Beta('OD: boat', 0, -100, 100, 1)
D_umbrella = Beta('OD: umbrella', 0, -100, 100, 1)
D_chair = Beta('OD: chair', 0, -100, 100, 1) ## SI VA

D_train = Beta('OD: train', 0, -100, 100, 1)## SI VA
D_potted_plant = Beta('OD: potted_plant', 0, -100, 100, 1)
D_stop_sign = Beta('OD: stop_sign', 0, -100, 100, 1)

D_bus = Beta('OD: bus', 0, -100, 100, 1)
D_motorcycle = Beta('OD: motorcycle', 0, -100, 100, 1)

# D_bike = Beta('OD: bike BC', 0, -100, 100, 1)
# D_person = Beta('OD: person', 0, -100, 100, 1)
# D_car = Beta('OD: car', 0, -100, 100, 1)

D_fire_hydrant = Beta('OD: fire_hydrant', 0, -100, 100, 1)

D_truck = Beta('OD: truck', 0, -100, 100, 0)
LAMBDA_truck = Beta('LAMBDA: truck',1,-5,5, 1)## SI VA

D_bike = Beta('OD: bike', 0, -100, 100, 0)
LAMBDA_bike = Beta('LAMBDA: bike',1,-5,5, 1)## SI VA

D_car = Beta('OD: car', 0, -100, 100, 0)## SI VA
LAMBDA_car = Beta('LAMBDA: car',1,0.1,15, 0)## SI VA

D_person = Beta('OD: person', -0.0691, -100, 100, 0)## SI VA
LAMBDA_person = Beta('LAMBDA: person',1,-5,5,1)## SI VA

D_light = Beta('OD: light', 0, -100, 100, 0)
LAMBDA_light = Beta('LAMBDA: light',1.0,0.0001,5,1)

# D_car_01 = Beta('OD: car 1', 0, -100, 100, 1)
# D_car_02 = Beta('OD: car 2', 0, -100, 100, 1)
# D_car_03 = Beta('OD: car 3', 0, -100, 100, 1)
# D_car_04 = Beta('OD: car 4', 0, -100, 100, 1)
# D_car_05 = Beta('OD: car 5', 0, -100, 100, 1)
# D_car_06 = Beta('OD: car 6', 0, -100, 100, 1)
# D_car_07 = Beta('OD: car 7', 0, -100, 100, 1)
# D_car_08 = Beta('OD: car 8', 0, -100, 100, 1)
# D_car_09 = Beta('OD: car 9', 0, -100, 100, 1)
# D_car_10 = Beta('OD: car 10', 0, -100, 100, 1)
# D_car_15 = Beta('OD: car 15', 0, -100, 100, 1)
# D_car_20 = Beta('OD: car 20', 0, -100, 100, 1)
# D_car_40 = Beta('OD: car 40+', 0, -100, 100, 1)

tau1	 = Beta('tau1',-1,None,0,0)
delta2	 = Beta('delta2',2,0,None,0)

tau2 = tau1 + delta2

G_Bicyclist_N = Beta('Female w/ HLF N: Bicyclist', 0, -100, 100, 1) 
G_Building_N = Beta('Female w/ HLF N: Building', 0, -100, 100, 1)
G_Car_N = Beta('Female w/ HLF N: Car', 0, -100, 100, 1) 
G_Fence_N = Beta('Female w/ HLF N: Fence', 0, -100, 100, 1) 
G_Pavement_N = Beta('Female w/ HLF N: Pavement', 0, -100, 100, 0)  # NS 0
G_Pedestrian_N = Beta('Female w/ HLF N: Pedestrian', 0, -100, 100, 1)
G_Pole_N = Beta('Female w/ HLF N: Pole', 0, -100, 100, 1) 
G_Road_N = Beta('Female w/ HLF N: Road', 0, -100, 100, 1)  # NS 0
G_SignSymbol_N = Beta('Female w/ HLF N: SignSymbol', 0, -100, 100, 1) 
G_Sky_N = Beta('Female w/ HLF N: Sky', 0, -100, 100, 1)
G_Tree_N = Beta('Female w/ HLF N: Tree', 0, -100, 100, 1)

G_Bicyclist_S = Beta('Female w/ HLF S: Bicyclist', 0, -100, 100, 1) 
G_Building_S = Beta('Female w/ HLF S: Building', 0, -100, 100, 1) 
G_Car_S = Beta('Female w/ HLF S: Car', 0, -100, 100, 1)
G_Fence_S = Beta('Female w/ HLF S: Fence', 0, -100, 100, 1) 
G_Pavement_S = Beta('Female w/ HLF S: Pavement', 0, -100, 100, 1)
G_Pedestrian_S = Beta('Female w/ HLF S: Pedestrian', 0, -100, 100, 1)
G_Pole_S = Beta('Female w/ HLF S: Pole', 0, -100, 100, 0)
G_Road_S = Beta('Female w/ HLF S: Road', 0, -100, 100, 1)
G_SignSymbol_S = Beta('Female w/ HLF S: SignSymbol', 0, -100, 100, 1)
G_Sky_S = Beta('Female w/ HLF S: Sky', 0, -100, 100, 1) # NS 0 
G_Tree_S = Beta('Female w/ HLF S: Tree', 0, -100, 100, 0) 

G_bench = Beta('Female w/ OD: bench', 0, -100, 100, 1)
G_boat = Beta('Female w/ OD: boat', 0, -100, 100, 1)
G_umbrella = Beta('Female w/ OD: umbrella', 0, -100, 100, 1)
G_chair = Beta('Female w/ OD: chair', 0, -100, 100, 1) ## SI VA

G_train = Beta('Female w/ OD: train', 0, -100, 100, 1)## SI VA
G_potted_plant = Beta('Female w/ OD: potted_plant', 0, -100, 100, 1)
G_stop_sign = Beta('Female w/ OD: stop_sign', 0, -100, 100, 1)
G_bus = Beta('Female w/ OD: bus', 0, -100, 100, 0)
G_motorcycle = Beta('Female w/ OD: motorcycle', 0, -100, 100, 1)

# G_person = Beta('Female w/ OD: person', 0, -100, 100, 0)
# G_car = Beta('Female w/ OD: car', 0, -100, 100, 0)
G_fire_hydrant = Beta('Female w/ OD: fire_hydrant', 0, -100, 100, 1)

G_truck = Beta('Female w/ OD: truck', 0, -100, 100, 1)
GAMMA_truck = Beta('Female w/ GAMMA: truck',1,-5,5, 0)## SI VA

G_bike = Beta('Female w/ OD: bike', 0, -100, 100, 1)
GAMMA_bike = Beta('Female w/ GAMMA: bike',1.0,-5,5, 0)## SI VA

G_car = Beta('Female w/ OD: car', 0, -100, 100, 0)## SI VA
GAMMA_car = Beta('Female w/ GAMMA: car',1.0,0.1,15, 0)## SI VA

G_person = Beta('Female w/ OD: person', 0, -100, 100, 0)## SI VA
GAMMA_person = Beta('Female w/ GAMMA: person',1.0,0.0001,5,0)## SI VA

G_light = Beta('Female w/ OD: light', 0, -100, 100, 1)
GAMMA_light = Beta('Female w/ GAMMA: light',1.0,0.0001,5,0)

PED_Fence_N = Beta('PED w/ HLF N: Fence', 0, -100, 100, 1)
PED_Pedestrian_N = Beta('PED w/ HLF N: Pedestrian', 0, -100, 100, 0)
PED_Car_S = Beta('PED w/ HLF S: Car', 0, -100, 100, 0)
PED_Pedestrian_S = Beta('PED w/ HLF S: Pedestrian', 0, -100, 100, 1)
PED_fire_hydrant = Beta('PED w/ OD: fire_hydrant', 0, -100, 100, 0)
PED_light = Beta('PED w/ OD: light', 0, -100, 100, 1)

BIKE_Bicyclist_N = Beta('Bike w/ HLF N: Bicyclist', 0, -100, 100, 1) 
BIKE_Pole_N = Beta('Bike w/ HLF N: Pole', 0, -100, 100, 0) 
BIKE_Sky_N = Beta('Bike w/ HLF N: Sky', 0, -100, 100, 0)
BIKE_bench = Beta('Bike w/ OD: bench', 0, -100, 100, 1)

PT_Pole_N = Beta('PT w/ HLF N: Pole', 0, -100, 100, 1) 
PT_Sky_N = Beta('PT w/ HLF N: Sky', 0, -100, 100, 1)
PT_Car_S = Beta('PT w/ HLF S: Car', 0, -100, 100, 0)
PT_stop_sign = Beta('PT w/ OD: stop_sign', 0, -100, 100, 0)

PT_bus = Beta('PT w/ OD: bus', 0, -100, 100, 0)

CAR_Tree_N = Beta('CAR w/ HLF N: Tree', 0, -100, 100, 1)
CAR_Building_S = Beta('CAR w/ HLF S: Building', 0, -100, 100, 0)
CAR_Pedestrian_S = Beta('CAR w/ HLF S: Pedestrian', 0, -100, 100, 0)
CAR_Road_S = Beta('CAR w/ HLF S: Road', 0, -100, 100, 0)

M12_Pedestrian_N = Beta('PED + BIKE w/ HLF N: Pedestrian', 0, -100, 100, 1)
M12_Pole_N = Beta('PED + BIKE w/ HLF N: Pole', 0, -100, 100, 1) 
M12_Sky_N = Beta('PED + BIKE w/ HLF N: Sky', 0, -100, 100, 1)
M12_SignSymbol_S = Beta('PED + BIKE w/ HLF S: SignSymbol', 0, -100, 100, 1)
M12_bench = Beta('PED + BIKE w/ OD: bench', 0, -100, 100, 0)


M23_Road_N = Beta('BIKE + PT w/ HLF N: Road', 0, -100, 100, 0)  # NS 0

# %%
U = B_mean_h * mean_h + \
     B_mean_l * mean_l + \
     B_mean_s * mean_s + \
     B_mean_bn * mean_bn + \
     B_stdev_h * stdev_h + \
     B_stdev_l * stdev_l + \
     B_stdev_s * stdev_s + \
     B_stdev_bn * stdev_bn + \
     B_edges * edges + \
     B_blobs * blobs + \
     B_Bicyclist_N * N_Bicyclist + \
     B_Building_N * N_Building + \
     B_Car_N * N_Car + \
     B_Fence_N * N_Fence + \
     B_Pavement_N * N_Pavement + \
     B_Pedestrian_N * N_Pedestrian + \
     B_Pole_N * N_Pole + \
     B_Road_N * N_Road + \
     B_SignSymbol_N * N_SignSymbol + \
     B_Sky_N * N_Sky + \
     B_Tree_N * N_Tree + \
     B_Bicyclist_S * S_Bicyclist + \
     B_Building_S * S_Building + \
     B_Car_S * S_Car + \
     B_Fence_S * S_Fence + \
     B_Pavement_S * S_Pavement + \
     B_Pedestrian_S * S_Pedestrian + \
     B_Pole_S * S_Pole + \
     B_Road_S * S_Road + \
     B_SignSymbol_S * S_SignSymbol + \
     B_Sky_S * S_Sky + \
     B_Tree_S * S_Tree + \
     D_bench * OD_bench + \
     D_chair * OD_chair + \
     D_fire_hydrant * OD_fire_hydrant + \
     D_potted_plant * OD_potted_plant + \
     D_stop_sign * OD_stop_sign + \
     D_train * OD_train + \
     D_umbrella * OD_umbrella + \
     D_bus * ( OD_bus_der - OD_bus_izq )+ \
     D_truck * (OD_truck_der) ** LAMBDA_truck - \
     D_truck * (OD_truck_izq) ** LAMBDA_truck + \
     D_person * (OD_person_der) ** LAMBDA_person - \
     D_person * (OD_person_izq) ** LAMBDA_person + \
     D_car * (OD_car_der)**LAMBDA_car - \
     D_car * (OD_car_izq)**LAMBDA_car + \
     D_light * (OD_traffic_light_der) ** LAMBDA_light - \
     D_light * (OD_traffic_light_izq) ** LAMBDA_light + \
     D_bike * (OD_bicycle_der) ** LAMBDA_bike - \
     D_bike * (OD_bicycle_izq) ** LAMBDA_bike + \
     gender * G_Bicyclist_N * N_Bicyclist + \
     gender * G_Building_N * N_Building + \
     gender * G_Car_N * N_Car + \
     gender * G_Fence_N * N_Fence + \
     gender * G_Pavement_N * N_Pavement + \
     gender * G_Pedestrian_N * N_Pedestrian + \
     gender * G_Pole_N * N_Pole + \
     gender * G_Road_N * N_Road + \
     gender * G_SignSymbol_N * N_SignSymbol + \
     gender * G_Sky_N * N_Sky + \
     gender * G_Tree_N * N_Tree + \
     gender * G_Bicyclist_S * S_Bicyclist + \
     gender * G_Building_S * S_Building + \
     gender * G_Car_S * S_Car + \
     gender * G_Fence_S * S_Fence + \
     gender * G_Pavement_S * S_Pavement + \
     gender * G_Pedestrian_S * S_Pedestrian + \
     gender * G_Pole_S * S_Pole + \
     gender * G_Road_S * S_Road + \
     gender * G_SignSymbol_S * S_SignSymbol + \
     gender * G_Sky_S * S_Sky + \
     gender * G_Tree_S * S_Tree + \
     gender * G_bench * OD_bench + \
     gender * G_chair * OD_chair + \
     gender * G_fire_hydrant * OD_fire_hydrant + \
     gender * G_potted_plant * OD_potted_plant + \
     gender * G_stop_sign * OD_stop_sign + \
     gender * G_train * OD_train + \
     gender * G_umbrella * OD_umbrella + \
     gender * G_bus * ( OD_bus_der - OD_bus_izq )+ \
     gender * G_truck * (OD_truck_der) ** LAMBDA_truck - \
     gender * G_truck * (OD_truck_izq) ** LAMBDA_truck + \
     gender * G_person * (OD_person_der)** LAMBDA_person - \
     gender * G_person * (OD_person_izq)** LAMBDA_person + \
     gender * G_car * (OD_car_der)** LAMBDA_car - \
     gender * G_car * (OD_car_izq)** LAMBDA_car + \
     gender * G_light * (OD_traffic_light_der) ** LAMBDA_light - \
     gender * G_light * (OD_traffic_light_izq) ** LAMBDA_light + \
     gender * G_bike * (OD_bicycle_der) ** LAMBDA_bike - \
     gender * G_bike * (OD_bicycle_izq) ** LAMBDA_bike + \
     (transport == 1) * PED_Pedestrian_N * N_Pedestrian + \
     (transport == 1) * PED_Pedestrian_S * S_Pedestrian + \
     (transport == 1) * PED_fire_hydrant * OD_fire_hydrant + \
     (transport == 1) * PED_Car_S * S_Car + \
     (transport == 1) * PED_Fence_N * N_Fence + \
     (transport == 1) * PED_light * (OD_traffic_light_der) ** LAMBDA_light - \
     (transport == 1) * PED_light * (OD_traffic_light_izq) ** LAMBDA_light + \
     (transport == 2) * BIKE_Bicyclist_N * N_Bicyclist + \
     (transport == 2) * BIKE_Pole_N * N_Pole + \
     (transport == 2) * BIKE_Sky_N * N_Sky + \
     (transport == 2) * BIKE_bench * OD_bench + \
     (transport == 3) * PT_stop_sign * OD_stop_sign + \
     (transport == 3) * PT_Car_S * S_Car + \
     (transport == 3) * PT_Pole_N * N_Pole + \
     (transport == 3) * PT_Sky_N * N_Sky + \
     (transport == 4) * CAR_Tree_N * N_Tree + \
     (transport == 4) * CAR_Building_S * S_Building + \
     (transport == 4) * CAR_Road_S * S_Road + \
     (transport == 4) * CAR_Pedestrian_S * S_Pedestrian + \
     ((transport == 1) + (transport == 2)) * M12_bench * OD_bench + \
     ((transport == 1) + (transport == 2)) * M12_Pole_N * N_Pole + \
     ((transport == 1) + (transport == 2)) * M12_Pedestrian_N * N_Pedestrian + \
     ((transport == 1) + (transport == 2)) * M12_Sky_N * N_Sky + \
     ((transport == 1) + (transport == 2)) * M12_SignSymbol_S * S_SignSymbol 

#      ((transport == 2) + (transport == 3)) * M23_Road_N * N_Road


#      ((transport == 2) + (transport == 3)) * VS_Bicyclist_N * N_Bicyclist + \
#      ((transport == 2) + (transport == 3)) * VS_Building_N * N_Building + \
#      ((transport == 2) + (transport == 3)) * VS_Car_N * N_Car + \
#      ((transport == 2) + (transport == 3)) * VS_Fence_N * N_Fence + \
#      ((transport == 2) + (transport == 3)) * VS_Pavement_N * N_Pavement + \
#      ((transport == 2) + (transport == 3)) * VS_Pedestrian_N * N_Pedestrian + \
#      ((transport == 2) + (transport == 3)) * VS_Pole_N * N_Pole + \
#      ((transport == 2) + (transport == 3)) * VS_Road_N * N_Road + \
#      ((transport == 2) + (transport == 3)) * VS_SignSymbol_N * N_SignSymbol + \
#      ((transport == 2) + (transport == 3)) * VS_Sky_N * N_Sky + \
#      ((transport == 2) + (transport == 3)) * VS_Tree_N * N_Tree + \
#      ((transport == 2) + (transport == 3)) * VS_Bicyclist_S * S_Bicyclist + \
#      ((transport == 2) + (transport == 3)) * VS_Building_S * S_Building + \
#      ((transport == 2) + (transport == 3)) * VS_Car_S * S_Car + \
#      ((transport == 2) + (transport == 3)) * VS_Fence_S * S_Fence + \
#      ((transport == 2) + (transport == 3)) * VS_Pavement_S * S_Pavement + \
#      ((transport == 2) + (transport == 3)) * VS_Pedestrian_S * S_Pedestrian + \
#      ((transport == 2) + (transport == 3)) * VS_Pole_S * S_Pole + \
#      ((transport == 2) + (transport == 3)) * VS_Road_S * S_Road + \
#      ((transport == 2) + (transport == 3)) * VS_SignSymbol_S * S_SignSymbol + \
#      ((transport == 2) + (transport == 3)) * VS_Sky_S * S_Sky + \
#      ((transport == 2) + (transport == 3)) * VS_Tree_S * S_Tree + \
#      ((transport == 2) + (transport == 3)) * VS_bench * OD_bench + \
#      ((transport == 2) + (transport == 3)) * VS_chair * OD_chair + \
#      ((transport == 2) + (transport == 3)) * VS_fire_hydrant * OD_fire_hydrant + \
#      ((transport == 2) + (transport == 3)) * VS_potted_plant * OD_potted_plant + \
#      ((transport == 2) + (transport == 3)) * VS_stop_sign * OD_stop_sign + \
#      ((transport == 2) + (transport == 3)) * VS_train * OD_train + \
#      ((transport == 2) + (transport == 3)) * VS_umbrella * OD_umbrella + \
#      ((transport == 2) + (transport == 3)) * VS_bus * ( OD_bus_der - OD_bus_izq )+ \
#      ((transport == 2) + (transport == 3)) * VS_truck * (OD_truck_der) ** LAMBDA_truck - \
#      ((transport == 2) + (transport == 3)) * VS_truck * (OD_truck_izq) ** LAMBDA_truck + \
#      ((transport == 2) + (transport == 3)) * VS_person * (OD_person_der)**LAMBDA_person - \
#      ((transport == 2) + (transport == 3)) * VS_person * (OD_person_izq)**LAMBDA_person + \
#      ((transport == 2) + (transport == 3)) * VS_car * (OD_car_der)**LAMBDA_car - \
#      ((transport == 2) + (transport == 3)) * VS_car * (OD_car_izq)**LAMBDA_car + \
#      ((transport == 2) + (transport == 3)) * VS_light * (OD_traffic_light_der) ** LAMBDA_light - \
#      ((transport == 2) + (transport == 3)) * VS_light * (OD_traffic_light_izq) ** LAMBDA_light + \
#      ((transport == 2) + (transport == 3)) * VS_bike * (OD_bicycle_der) ** LAMBDA_bike - \
#      ((transport == 2) + (transport == 3)) * VS_bike * (OD_bicycle_izq) ** LAMBDA_bike

# %%
P1 = 1-dist.logisticcdf(U-tau1)
P2 = dist.logisticcdf(U-tau2)
Pe = dist.logisticcdf(U-tau1)- dist.logisticcdf(U-tau2)

ChoiceProba = {
    1: P1,
    3: Pe,
    2: P2}

# bioNormalCdf
# logisticcdf
choice = 1

logprob = log(Elem(ChoiceProba,choice))
formulas = {'loglike':logprob,
           'Prob 1':P1,
           'Prob =':Pe,
           'Prob 2':P2,
           'Utilidad':U}

# %%
# model = './../04 Modelos/__ Definitivos/22 safety - VS.pickle'
model = './../04 Modelos/__ Definitivos/_Paper-OD.pickle'
results = res.bioResults(pickleFile = model)

betas = dict()
for i in range(len(results.data.betaValues)):
    betas[results.data.betaNames[i]] = results.data.betaValues[i]

df_eval = pd.read_csv('./../00 Insumos/02 Stgo/data_aplicacion.csv')
# features = pd.read_csv('./../../03 Respuestas/new_features_imagenes.csv')

# %%
betas
# Out:
# {'HLF N: Building': 0.793017458929846,
#  'HLF N: Car': -0.9278911374638381,
#  'HLF N: Fence': 0.8845587171044378,
#  'HLF N: Pavement': -2.164254265201766,
#  'HLF N: Pole': -1.7170715647891903,
#  'HLF N: SignSymbol': 1.8318438439993,
#  'HLF N: Sky': -1.2946881928595257,
#  'HLF N: Tree': 0.9923194971131747,
#  'HLF S: Car': 1.108016245144357,
#  'HLF S: Pole': -2.4533114728030334,
#  'HLF S: Road': 2.356602246010053,
#  'HLF S: Tree': 1.9186213521190576,
#  'LAMBDA: car': 0.44893741286707967,
#  'LLF: edges': 8.138163859815412,
#  'LLF: mean_h': -0.0016412391259496258,
#  'LLF: mean_l': 0.0051807310996225975,
#  'LLF: mean_s': -0.010892804667522571,
#  'LLF: stdev_h': 0.015435845471235235,
#  'LLF: stdev_l': 0.009441826727591637,
#  'LLF: stdev_s': 0.0177783531056694,
#  'OD: bike': 0.1818900076666893,
#  'OD: car': 0.10329021478703392,
#  'OD: person': 0.04153731395632568,
#  'OD: truck': -0.09214191198316368,
#  'delta2': 0.9167054206417827,
#  'tau1': -0.4784571212785716}

# %%
df_eval['transport'] = 0
df_eval['gender'] = 0
df_eval['choice'] = 1

database = db.Database("database",df_eval)

biogeme = bio.BIOGEME(database,formulas,numberOfThreads=8)
sim_od = biogeme.simulate(betas)

# %%
# model = './../04 Modelos/__ Definitivos/22 safety - VS.pickle'
# model = './../04 Modelos/__ Definitivos/_Paper-OD.pickle'
model = './../04 Modelos/__ Definitivos/_Paper-VS.pickle'
results = res.bioResults(pickleFile = model)

betas = dict()
for i in range(len(results.data.betaValues)):
    betas[results.data.betaNames[i]] = results.data.betaValues[i]

df_eval = pd.read_csv('./../00 Insumos/02 Stgo/data_aplicacion.csv')
# features = pd.read_csv('./../../03 Respuestas/new_features_imagenes.csv')

# %%
betas
# Out:
# {'Bike w/ HLF N: Pole': 3.3182083605472092,
#  'Bike w/ HLF N: Sky': -0.8898758078649189,
#  'Bike w/ OD: bench': 2.194887377743369,
#  'CAR w/ HLF S: Building': -1.087270064284355,
#  'CAR w/ HLF S: Pedestrian': 3.8336503871169834,
#  'CAR w/ HLF S: Road': -1.9932502759159383,
#  'Female w/ HLF N: Pavement': -3.725968419101279,
#  'Female w/ HLF S: Pole': -1.841070465380215,
#  'Female w/ HLF S: Tree': -0.9673175944240611,
#  'Female w/ OD: bus': -0.2158153168797947,
#  'Female w/ OD: car': -0.0642218514974976,
#  'Female w/ OD: person': -0.09026073754163642,
#  'HLF N: Building': 0.7655517215578799,
#  'HLF N: Car': -0.9636398317911173,
#  'HLF N: Fence': 0.8161295847461527,
#  'HLF N: Pole': -2.454640031085417,
#  'HLF N: SignSymbol': 1.8806464958081939,
#  'HLF N: Sky': -1.021624423253293,
#  'HLF N: Tree': 1.072996934634494,
#  'HLF S: Pole': -1.8694054253593622,
#  'HLF S: Road': 2.6570052017887997,
#  'HLF S: Tree': 2.250696428659754,
#  'LAMBDA: car': 0.5339071936106966,
#  'LLF: edges': 8.654315028063959,
#  'LLF: mean_h': -0.0016652736881895558,
#  'LLF: mean_l': 0.005899793538851795,
#  'LLF: mean_s': -0.009434894647639502,
#  'LLF: stdev_h': 0.01574695780845489,
#  'LLF: stdev_l': 0.009096137138807156,
#  'LLF: stdev_s': 0.01662548465947084,
#  'OD: bike': 0.18150070031060944,
#  'OD: car': 0.11948242073828957,
#  'OD: person': 0.06191551898479617,
#  'OD: truck': -0.09699604748002849,
#  'PED w/ HLF N: Pedestrian': 15.018682758672691,
#  'PED w/ HLF S: Car': 1.755589035088831,
#  'PT w/ HLF S: Car': 1.4880074884665928,
#  'delta2': 0.927737108288034,
#  'tau1': -0.4844087024182507}

# %%
df_eval['transport'] = 0
df_eval['gender'] = 0
df_eval['choice'] = 1

database = db.Database("database",df_eval)

biogeme = bio.BIOGEME(database,formulas,numberOfThreads=8)
sim_male = biogeme.simulate(betas)

# %%
df_eval.loc[:,'gender'] = 1

database = db.Database("database",df_eval)

biogeme = bio.BIOGEME(database,formulas,numberOfThreads=8)
sim_female = biogeme.simulate(betas)

# %%
df_eval.loc[:,'transport'] = 1
df_eval.loc[:,'gender'] = 0

database = db.Database("database",df_eval)

biogeme = bio.BIOGEME(database,formulas,numberOfThreads=8)
sim_pedestrian = biogeme.simulate(betas)

# %%
df_eval.loc[:,'transport'] = 2

database = db.Database("database",df_eval)

biogeme = bio.BIOGEME(database,formulas,numberOfThreads=8)
sim_bike = biogeme.simulate(betas)

# %%
df_eval.loc[:,'transport'] = 3
database = db.Database("database",df_eval)

biogeme = bio.BIOGEME(database,formulas,numberOfThreads=8)
sim_PT = biogeme.simulate(betas)

# %%
df_eval.loc[:,'transport'] = 4

database = db.Database("database",df_eval)

biogeme = bio.BIOGEME(database,formulas,numberOfThreads=8)
sim_car = biogeme.simulate(betas)

# %%
score = pd.DataFrame(sim_male['Utilidad'])
score = score.join(sim_female['Utilidad'],how='left',rsuffix='_female')
score = score.join(sim_pedestrian['Utilidad'],how='left',rsuffix='_pedestrian')
score = score.join(sim_bike['Utilidad'],how='left',rsuffix='_bike')
score = score.join(sim_PT['Utilidad'],how='left',rsuffix='_PT')
score = score.join(sim_car['Utilidad'],how='left',rsuffix='_car')
score = score.join(sim_od['Utilidad'],how='left',rsuffix='_OD')
score.rename(columns={'Utilidad':'Utilidad_male'}, inplace=True)

# %%
score.describe()
# Out:
#        Utilidad_male  Utilidad_female  Utilidad_pedestrian  Utilidad_bike  \
# count  126286.000000    126286.000000        126286.000000  126286.000000
# mean        3.776284         3.202575             4.062896       3.852115
# std         0.598043         0.615205             0.688602       0.643189
# min        -0.502750        -1.083456            -0.502750      -0.502750
# 25%         3.371597         2.807232             3.600103       3.406757
# 50%         3.756492         3.202806             4.025470       3.820464
# 75%         4.167272         3.606832             4.492590       4.277620
# max         6.366838         5.633422             8.730444       6.511866
#
#          Utilidad_PT   Utilidad_car    Utilidad_OD
# count  126286.000000  126286.000000  126286.000000
# mean        3.959705       3.087863       3.379865
# std         0.634804       0.641229       0.585364
# min        -0.502750      -0.502750      -1.004080
# 25%         3.532560       2.644894       2.978240
# 50%         3.939566       3.056515       3.356683
# 75%         4.371886       3.506590       3.765828
# max         6.703756       5.802340       5.877116

# %%
score.corr()
# Out:
#                      Utilidad_male  Utilidad_female  Utilidad_pedestrian  \
# Utilidad_male             1.000000         0.940365             0.915768
# Utilidad_female           0.940365         1.000000             0.835100
# Utilidad_pedestrian       0.915768         0.835100             1.000000
# Utilidad_bike             0.967003         0.880259             0.918006
# Utilidad_PT               0.975026         0.914578             0.953401
# Utilidad_car              0.950026         0.883182             0.877209
# Utilidad_OD               0.995245         0.940232             0.921597
#
#                      Utilidad_bike  Utilidad_PT  Utilidad_car  Utilidad_OD
# Utilidad_male             0.967003     0.975026      0.950026     0.995245
# Utilidad_female           0.880259     0.914578      0.883182     0.940232
# Utilidad_pedestrian       0.918006     0.953401      0.877209     0.921597
# Utilidad_bike             1.000000     0.948275      0.916845     0.978927
# Utilidad_PT               0.948275     1.000000      0.930023     0.972698
# Utilidad_car              0.916845     0.930023      1.000000     0.945962
# Utilidad_OD               0.978927     0.972698      0.945962     1.000000

# %%
# score['D_female'] = score['Utilidad'] - score['Utilidad_female']
# score['D_pedestrian'] = score['Utilidad'] - score['Utilidad_pedestrian']
# score['D_bike'] = score['Utilidad'] - score['Utilidad_bike']
# score['D_PT'] = score['Utilidad'] - score['Utilidad_PT']
# score['D_car'] = score['Utilidad'] - score['Utilidad_car']

# %%
features = pd.read_csv('./../00 Insumos/02 Stgo/all_features_imagenes.csv')
# Out:
# C:\Users\Tom\Anaconda3\envs\bio\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
perception = pd.concat([features['ID'],score], axis=1)
# perception = pd.concat([features['ID'],score.iloc[:,0]], axis=1)

# %%
perception
# .corr()
# Out:
#                                            ID  Utilidad_male  Utilidad_female  \
# 0               -33.323944,-70.51263428391168       3.696734         3.183997
# 1                      -33.323944,-70.5127291       3.753128         3.294236
# 2               -33.323944,-70.51298714285714       4.063147         3.675854
# 3               -33.323944,-70.51343609999999       3.685047         3.167897
# 4               -33.323944,-70.51379769565217       3.537364         2.535822
# ...                                       ...            ...              ...
# 126281  -33.67884090851735,-70.68059514195582       2.501214         2.037337
# 126282  -33.67884090851735,-70.69912023659306       3.770969         3.272160
# 126283  -33.67884090851735,-70.70653027444796       3.835170         3.423882
# 126284   -33.67884090851735,-70.7176453312303       3.073325         2.541004
# 126285  -33.67884090851735,-70.72505536908517       3.307779         2.852556
#
#         Utilidad_pedestrian  Utilidad_bike  Utilidad_PT  Utilidad_car  \
# 0                  3.699778       3.668958     3.699314      2.776589
# 1                  3.935767       3.778827     3.819058      2.765525
# 2                  4.143802       3.983864     4.131509      3.232608
# 3                  5.082386       3.895684     4.063870      2.806048
# 4                  3.577750       3.692063     3.540796      2.683966
# ...                     ...            ...          ...           ...
# 126281             2.501420       2.332108     2.501388      1.725374
# 126282             3.787936       3.785730     3.785350      3.206583
# 126283             3.835170       3.863277     3.835170      3.530169
# 126284             3.112770       2.912668     3.106758      3.036138
# 126285             3.440150       3.325864     3.419975      3.068400
#
#         Utilidad_OD
# 0          3.223736
# 1          3.341979
# 2          3.645334
# 3          3.346853
# 4          3.143030
# ...             ...
# 126281     2.059656
# 126282     3.341146
# 126283     3.436854
# 126284     2.636880
# 126285     2.952673
#
# [126286 rows x 8 columns]

# %%
perception.to_csv('puntajes_safety_OD.csv')

# %%
# import matplotlib.pyplot as plt
# import requests
# from PIL import Image
# from io import BytesIO
# from io import StringIO

# %%
url_base = 'http://wekun.ing.puc.cl/static/img/'

for image_id in diff.sort_values('DIF').iloc[:5,[0]].values:
    url = url_base + image_id[0] + '.jpg'
    response = requests.get(url)
    image = Image.open(BytesIO(response.content))
    plt.imshow(image)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f33d709a0aff> in <module>
#       1 url_base = 'http://wekun.ing.puc.cl/static/img/'
#       2
# ----> 3 for image_id in diff.sort_values('DIF').iloc[:5,[0]].values:
#       4     url = url_base + image_id[0] + '.jpg'
#       5     response = requests.get(url)
#
# NameError: name 'diff' is not defined
