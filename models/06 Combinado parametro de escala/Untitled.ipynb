# %%
import pandas as pd
import biogeme.database as db
import biogeme.biogeme as bio
import biogeme.distributions as dist
import biogeme.models as models
import biogeme.results as res

# %%
data = pd.read_csv('./../log_data.dat',sep='\t', decimal='.')
# data = data[(data['question'] == 1) | (data['question'] == 2) ]
database = db.Database("database",data)
from headers import *

# %%
B_mean_h = Beta('LLF: mean_h', 0, -100, 100, 0)
B_mean_l = Beta('LLF: mean_l', 0, -100, 100, 0)
B_mean_s = Beta('LLF: mean_s', 0, -100, 100, 0)
B_mean_bn = Beta('LLF: mean_bn', 0, -100, 100, 1)  # NS
B_stdev_h = Beta('LLF: stdev_h', 0, -100, 100, 0)
B_stdev_l = Beta('LLF: stdev_l', 0, -100, 100, 0)
B_stdev_s = Beta('LLF: stdev_s', 0, -100, 100, 0)
B_stdev_bn = Beta('LLF: stdev_bn', 0, -100, 100, 1)  # NS

B_edges = Beta('LLF: edges', 0, -100, 100, 0)
B_blobs = Beta('LLF: blobs', 0, -100, 100, 1)

# %%
B1_Bicyclist_N = Beta('HLF N 1: Bicyclist', 0, -100, 100, 0) 
B1_Building_N = Beta('HLF N 1: Building', 0, -100, 100, 1)
B1_Car_N = Beta('HLF N 1: Car', 0, -100, 100, 0) 
B1_Fence_N = Beta('HLF N 1: Fence', 0, -100, 100, 0) 
B1_Pavement_N = Beta('HLF N 1: Pavement', 0, -100, 100, 0)  # NS 0
B1_Pedestrian_N = Beta('HLF N 1: Pedestrian', 0, -100, 100, 1)
B1_Pole_N = Beta('HLF N 1: Pole', 0, -100, 100, 1) 
B1_Road_N = Beta('HLF N 1: Road', 0, -100, 100, 1)  # NS 0
B1_SignSymbol_N = Beta('HLF N 1: SignSymbol', 0, -100, 100, 0) 
B1_Sky_N = Beta('HLF N 1: Sky', 0, -100, 100, 0)
B1_Tree_N = Beta('HLF N 1: Tree', 0, -100, 100, 0)

B1_Bicyclist_S = Beta('HLF S 1: Bicyclist', 0, -100, 100, 1) 
B1_Building_S = Beta('HLF S 1: Building', 0, -100, 100, 0) 
B1_Car_S = Beta('HLF S 1: Car', 0, -100, 100, 1)
B1_Fence_S = Beta('HLF S 1: Fence', 0, -100, 100, 0) 
B1_Pavement_S = Beta('HLF S 1: Pavement', 0, -100, 100, 0)
B1_Pedestrian_S = Beta('HLF S 1: Pedestrian', 0, -100, 100, 0)
B1_Pole_S = Beta('HLF S 1: Pole', 0, -100, 100, 0)
B1_Road_S = Beta('HLF S 1: Road', 0, -100, 100, 0)
B1_SignSymbol_S = Beta('HLF S 1: SignSymbol', 0, -100, 100, 0)
B1_Sky_S = Beta('HLF S 1: Sky', 0, -100, 100, 1) # NS 0 
B1_Tree_S = Beta('HLF S 1: Tree', 0, -100, 100, 0)

# %%
B2_Bicyclist_N = Beta('HLF N 2: Bicyclist', 0, -100, 100, 1) 
B2_Building_N = Beta('HLF N 2: Building', 0, -100, 100, 1)
B2_Car_N = Beta('HLF N 2: Car', 0, -100, 100, 0) 
B2_Fence_N = Beta('HLF N 2: Fence', 0, -100, 100, 0) 
B2_Pavement_N = Beta('HLF N 2: Pavement', 0, -100, 100, 0)  # NS 0
B2_Pedestrian_N = Beta('HLF N 2: Pedestrian', 0, -100, 100, 1)
B2_Pole_N = Beta('HLF N 2: Pole', 0, -100, 100, 0) 
B2_Road_N = Beta('HLF N 2: Road', 0, -100, 100, 1)  # NS 0
B2_SignSymbol_N = Beta('HLF N 2: SignSymbol', 0, -100, 100, 0) 
B2_Sky_N = Beta('HLF N 2: Sky', 0, -100, 100, 1)
B2_Tree_N = Beta('HLF N 2: Tree', 0, -100, 100, 1)

B2_Bicyclist_S = Beta('HLF S 2: Bicyclist', 0, -100, 100, 1)
B2_Building_S = Beta('HLF S 2: Building', 0, -100, 100, 1) 
B2_Car_S = Beta('HLF S 2: Car', 0, -100, 100, 0)
B2_Fence_S = Beta('HLF S 2: Fence', 0, -100, 100, 0) 
B2_Pavement_S = Beta('HLF S 2: Pavement', 0, -100, 100, 0)
B2_Pedestrian_S = Beta('HLF S 2: Pedestrian', 0, -100, 100, 1)
B2_Pole_S = Beta('HLF S 2: Pole', 0, -100, 100, 0)
B2_Road_S = Beta('HLF S 2: Road', 0, -100, 100, 0)
B2_SignSymbol_S = Beta('HLF S 2: SignSymbol', 0, -100, 100, 1)
B2_Sky_S = Beta('HLF S 2: Sky', 0, -100, 100, 1) # NS 0 
B2_Tree_S = Beta('HLF S 2: Tree', 0, -100, 100, 0)

# %%
B3_Bicyclist_N = Beta('HLF N 3: Bicyclist', 0, -100, 100, 1) 
B3_Building_N = Beta('HLF N 3: Building', 0, -100, 100, 0)
B3_Car_N = Beta('HLF N 3: Car', 0, -100, 100, 0) 
B3_Fence_N = Beta('HLF N 3: Fence', 0, -100, 100, 0) 
B3_Pavement_N = Beta('HLF N 3: Pavement', 0, -100, 100, 0)  # NS 0
B3_Pedestrian_N = Beta('HLF N 3: Pedestrian', 0, -100, 100, 1)
B3_Pole_N = Beta('HLF N 3: Pole', 0, -100, 100, 0) 
B3_Road_N = Beta('HLF N 3: Road', 0, -100, 100, 1)  # NS 0
B3_SignSymbol_N = Beta('HLF N 3: SignSymbol', 0, -100, 100, 0) 
B3_Sky_N = Beta('HLF N 3: Sky', 0, -100, 100, 0)
B3_Tree_N = Beta('HLF N 3: Tree', 0, -100, 100, 0)

B3_Bicyclist_S = Beta('HLF S 3: Bicyclist', 0, -100, 100, 1) 
B3_Building_S = Beta('HLF S 3: Building', 0, -100, 100, 1) 
B3_Car_S = Beta('HLF S 3: Car', 0, -100, 100, 0)
B3_Fence_S = Beta('HLF S 3: Fence', 0, -100, 100, 1) 
B3_Pavement_S = Beta('HLF S 3: Pavement', 0, -100, 100, 1)
B3_Pedestrian_S = Beta('HLF S 3: Pedestrian', 0, -100, 100, 1)
B3_Pole_S = Beta('HLF S 3: Pole', 0, -100, 100, 0)
B3_Road_S = Beta('HLF S 3: Road', 0, -100, 100, 0)
B3_SignSymbol_S = Beta('HLF S 3: SignSymbol', 0, -100, 100, 1)
B3_Sky_S = Beta('HLF S 3: Sky', 0, -100, 100, 1) # NS 0 
B3_Tree_S = Beta('HLF S 3: Tree', 0, -100, 100, 0)

# %%
B4_Bicyclist_N = Beta('HLF N 4: Bicyclist', 0, -100, 100, 0) 
B4_Building_N = Beta('HLF N 4: Building', 0, -100, 100, 0)
B4_Car_N = Beta('HLF N 4: Car', 0, -100, 100, 0) 
B4_Fence_N = Beta('HLF N 4: Fence', 0, -100, 100, 0) 
B4_Pavement_N = Beta('HLF N 4: Pavement', 0, -100, 100, 0)  # NS 0
B4_Pedestrian_N = Beta('HLF N 4: Pedestrian', 0, -100, 100, 1)
B4_Pole_N = Beta('HLF N 4: Pole', 0, -100, 100, 1) 
B4_Road_N = Beta('HLF N 4: Road', 0, -100, 100, 1)  # NS 0
B4_SignSymbol_N = Beta('HLF N 4: SignSymbol', 0, -100, 100, 0) 
B4_Sky_N = Beta('HLF N 4: Sky', 0, -100, 100, 0)
B4_Tree_N = Beta('HLF N 4: Tree', 0, -100, 100, 1)

B4_Bicyclist_S = Beta('HLF S 4: Bicyclist', 0, -100, 100, 1) 
B4_Building_S = Beta('HLF S 4: Building', 0, -100, 100, 0) 
B4_Car_S = Beta('HLF S 4: Car', 0, -100, 100, 0)
B4_Fence_S = Beta('HLF S 4: Fence', 0, -100, 100, 0) 
B4_Pavement_S = Beta('HLF S 4: Pavement', 0, -100, 100, 0)
B4_Pedestrian_S = Beta('HLF S 4: Pedestrian', 0, -100, 100, 1)
B4_Pole_S = Beta('HLF S 4: Pole', 0, -100, 100, 0)
B4_Road_S = Beta('HLF S 4: Road', 0, -100, 100, 0)
B4_SignSymbol_S = Beta('HLF S 4: SignSymbol', 0, -100, 100, 1)
B4_Sky_S = Beta('HLF S 4: Sky', 0, -100, 100, 1) # NS 0 
B4_Tree_S = Beta('HLF S 4: Tree', 0, -100, 100, 0)

# %%
B5_Bicyclist_N = Beta('HLF N 5: Bicyclist', 0, -100, 100, 1) 
B5_Building_N = Beta('HLF N 5: Building', 0, -100, 100, 1)
B5_Car_N = Beta('HLF N 5: Car', 0, -100, 100, 0) 
B5_Fence_N = Beta('HLF N 5: Fence', 0, -100, 100, 0) 
B5_Pavement_N = Beta('HLF N 5: Pavement', 0, -100, 100, 0)  # NS 0
B5_Pedestrian_N = Beta('HLF N 5: Pedestrian', 0, -100, 100, 1)
B5_Pole_N = Beta('HLF N 5: Pole', 0, -100, 100, 1) 
B5_Road_N = Beta('HLF N 5: Road', 0, -100, 100, 1)  # NS 0
B5_SignSymbol_N = Beta('HLF N 5: SignSymbol', 0, -100, 100, 1) 
B5_Sky_N = Beta('HLF N 5: Sky', 0, -100, 100, 1)
B5_Tree_N = Beta('HLF N 5: Tree', 0, -100, 100, 1)

B5_Bicyclist_S = Beta('HLF S 5: Bicyclist', 0, -100, 100, 1) 
B5_Building_S = Beta('HLF S 5: Building', 0, -100, 100, 1) 
B5_Car_S = Beta('HLF S 5: Car', 0, -100, 100, 1)
B5_Fence_S = Beta('HLF S 5: Fence', 0, -100, 100, 1) 
B5_Pavement_S = Beta('HLF S 5: Pavement', 0, -100, 100, 1)
B5_Pedestrian_S = Beta('HLF S 5: Pedestrian', 0, -100, 100, 1)
B5_Pole_S = Beta('HLF S 5: Pole', 0, -100, 100, 0)
B5_Road_S = Beta('HLF S 5: Road', 0, -100, 100, 0)
B5_SignSymbol_S = Beta('HLF S 5: SignSymbol', 0, -100, 100, 1)
B5_Sky_S = Beta('HLF S 5: Sky', 0, -100, 100, 1) # NS 0 
B5_Tree_S = Beta('HLF S 5: Tree', 0, -100, 100, 0)

# %%
MU2 = Beta('MU: Live',1.0,-5,5,0)
MU3 = Beta('MU: Safety',1.0,-5,5,0)
MU4 = Beta('MU: Beauty',1.0,-5,5,0)
MU5 = Beta('MU: Wealthy',1.0,-5,5,0)


tau1	 = Beta('tau1',-1,None,0,0)
delta2	 = Beta('delta2',2,0,None,0)

tau2 = tau1 + delta2

# %%
U1 =  B_mean_h * mean_h + \
     B_mean_l * mean_l + \
     B_mean_s * mean_s + \
     B_mean_bn * mean_bn + \
     B_stdev_h * stdev_h + \
     B_stdev_l * stdev_l + \
     B_stdev_s * stdev_s + \
     B_stdev_bn * stdev_bn + \
     B_edges * edges + \
     B_blobs * blobs + \
     B1_Bicyclist_N * N_Bicyclist + \
     B1_Building_N * N_Building + \
     B1_Car_N * N_Car + \
     B1_Fence_N * N_Fence + \
     B1_Pavement_N * N_Pavement + \
     B1_Pedestrian_N * N_Pedestrian + \
     B1_Pole_N * N_Pole + \
     B1_Road_N * N_Road + \
     B1_SignSymbol_N * N_SignSymbol + \
     B1_Sky_N * N_Sky + \
     B1_Tree_N * N_Tree + \
     B1_Bicyclist_S * S_Bicyclist + \
     B1_Building_S * S_Building + \
     B1_Car_S * S_Car + \
     B1_Fence_S * S_Fence + \
     B1_Pavement_S * S_Pavement + \
     B1_Pedestrian_S * S_Pedestrian + \
     B1_Pole_S * S_Pole + \
     B1_Road_S * S_Road + \
     B1_SignSymbol_S * S_SignSymbol + \
     B1_Sky_S * S_Sky + \
     B1_Tree_S * S_Tree

U2 =  B_mean_h * mean_h + \
     B_mean_l * mean_l + \
     B_mean_s * mean_s + \
     B_mean_bn * mean_bn + \
     B_stdev_h * stdev_h + \
     B_stdev_l * stdev_l + \
     B_stdev_s * stdev_s + \
     B_stdev_bn * stdev_bn + \
     B_edges * edges + \
     B_blobs * blobs + \
     B2_Bicyclist_N * N_Bicyclist + \
     B2_Building_N * N_Building + \
     B2_Car_N * N_Car + \
     B2_Fence_N * N_Fence + \
     B2_Pavement_N * N_Pavement + \
     B2_Pedestrian_N * N_Pedestrian + \
     B2_Pole_N * N_Pole + \
     B2_Road_N * N_Road + \
     B2_SignSymbol_N * N_SignSymbol + \
     B2_Sky_N * N_Sky + \
     B2_Tree_N * N_Tree + \
     B2_Bicyclist_S * S_Bicyclist + \
     B2_Building_S * S_Building + \
     B2_Car_S * S_Car + \
     B2_Fence_S * S_Fence + \
     B2_Pavement_S * S_Pavement + \
     B2_Pedestrian_S * S_Pedestrian + \
     B2_Pole_S * S_Pole + \
     B2_Road_S * S_Road + \
     B2_SignSymbol_S * S_SignSymbol + \
     B2_Sky_S * S_Sky + \
     B2_Tree_S * S_Tree

U3 =  B_mean_h * mean_h + \
     B_mean_l * mean_l + \
     B_mean_s * mean_s + \
     B_mean_bn * mean_bn + \
     B_stdev_h * stdev_h + \
     B_stdev_l * stdev_l + \
     B_stdev_s * stdev_s + \
     B_stdev_bn * stdev_bn + \
     B_edges * edges + \
     B_blobs * blobs + \
     B3_Bicyclist_N * N_Bicyclist + \
     B3_Building_N * N_Building + \
     B3_Car_N * N_Car + \
     B3_Fence_N * N_Fence + \
     B3_Pavement_N * N_Pavement + \
     B3_Pedestrian_N * N_Pedestrian + \
     B3_Pole_N * N_Pole + \
     B3_Road_N * N_Road + \
     B3_SignSymbol_N * N_SignSymbol + \
     B3_Sky_N * N_Sky + \
     B3_Tree_N * N_Tree + \
     B3_Bicyclist_S * S_Bicyclist + \
     B3_Building_S * S_Building + \
     B3_Car_S * S_Car + \
     B3_Fence_S * S_Fence + \
     B3_Pavement_S * S_Pavement + \
     B3_Pedestrian_S * S_Pedestrian + \
     B3_Pole_S * S_Pole + \
     B3_Road_S * S_Road + \
     B3_SignSymbol_S * S_SignSymbol + \
     B3_Sky_S * S_Sky + \
     B3_Tree_S * S_Tree

U4 =  B_mean_h * mean_h + \
     B_mean_l * mean_l + \
     B_mean_s * mean_s + \
     B_mean_bn * mean_bn + \
     B_stdev_h * stdev_h + \
     B_stdev_l * stdev_l + \
     B_stdev_s * stdev_s + \
     B_stdev_bn * stdev_bn + \
     B_edges * edges + \
     B_blobs * blobs + \
     B4_Bicyclist_N * N_Bicyclist + \
     B4_Building_N * N_Building + \
     B4_Car_N * N_Car + \
     B4_Fence_N * N_Fence + \
     B4_Pavement_N * N_Pavement + \
     B4_Pedestrian_N * N_Pedestrian + \
     B4_Pole_N * N_Pole + \
     B4_Road_N * N_Road + \
     B4_SignSymbol_N * N_SignSymbol + \
     B4_Sky_N * N_Sky + \
     B4_Tree_N * N_Tree + \
     B4_Bicyclist_S * S_Bicyclist + \
     B4_Building_S * S_Building + \
     B4_Car_S * S_Car + \
     B4_Fence_S * S_Fence + \
     B4_Pavement_S * S_Pavement + \
     B4_Pedestrian_S * S_Pedestrian + \
     B4_Pole_S * S_Pole + \
     B4_Road_S * S_Road + \
     B4_SignSymbol_S * S_SignSymbol + \
     B4_Sky_S * S_Sky + \
     B4_Tree_S * S_Tree

U5 =  B_mean_h * mean_h + \
     B_mean_l * mean_l + \
     B_mean_s * mean_s + \
     B_mean_bn * mean_bn + \
     B_stdev_h * stdev_h + \
     B_stdev_l * stdev_l + \
     B_stdev_s * stdev_s + \
     B_stdev_bn * stdev_bn + \
     B_edges * edges + \
     B_blobs * blobs + \
     B5_Bicyclist_N * N_Bicyclist + \
     B5_Building_N * N_Building + \
     B5_Car_N * N_Car + \
     B5_Fence_N * N_Fence + \
     B5_Pavement_N * N_Pavement + \
     B5_Pedestrian_N * N_Pedestrian + \
     B5_Pole_N * N_Pole + \
     B5_Road_N * N_Road + \
     B5_SignSymbol_N * N_SignSymbol + \
     B5_Sky_N * N_Sky + \
     B5_Tree_N * N_Tree + \
     B5_Bicyclist_S * S_Bicyclist + \
     B5_Building_S * S_Building + \
     B5_Car_S * S_Car + \
     B5_Fence_S * S_Fence + \
     B5_Pavement_S * S_Pavement + \
     B5_Pedestrian_S * S_Pedestrian + \
     B5_Pole_S * S_Pole + \
     B5_Road_S * S_Road + \
     B5_SignSymbol_S * S_SignSymbol + \
     B5_Sky_S * S_Sky + \
     B5_Tree_S * S_Tree

# %%
U = (choice == 1) * U1 + \
    (choice == 2) * MU2 * U2 + \
    (choice == 3) * MU3 * U3 + \
    (choice == 4) * MU4 * U4 + \
    (choice == 5) * MU5 * U5

# %%
P1 = 1-dist.logisticcdf(U-tau1)
P2 = dist.logisticcdf(U-tau2)
Pe = dist.logisticcdf(U-tau1)- dist.logisticcdf(U-tau2)

ChoiceProba = {
    1: P1,
    3: Pe,
    2: P2}

# bioNormalCdf
# logisticcdf

logprob = log(Elem(ChoiceProba,choice))
formulas = {'loglike':logprob,
           'Prob 1':P1,
           'Prob =':Pe,
           'Prob 2':P2,
           'Utilidad':U}

biogeme = bio.BIOGEME(database,formulas,numberOfThreads=8)

biogeme.modelName = "COMBO-Todo"
# biogeme.cfsqp(0,0)
# results = biogeme.estimate()

## algorithms
results = biogeme.estimate(algorithm=None)
R = results.getEstimatedParameters()

B = pd.DataFrame(R['Value'])
T = pd.DataFrame(R['t-test'])

# B = pd.concat([B,R['Value']],axis=1, sort=False)
# T = pd.concat([T,R['t-test']],axis=1, sort=False)

# %%
T[0:30]
# Out:
#                        t-test
# HLF N 1: Bicyclist   2.152454
# HLF N 1: Car        -5.791027
# HLF N 1: Fence       5.378579
# HLF N 1: Pavement   -7.916138
# HLF N 1: SignSymbol  4.662417
# HLF N 1: Sky        -5.270204
# HLF N 1: Tree        4.012096
# HLF N 2: Car        -4.890641
# HLF N 2: Fence       6.127319
# HLF N 2: Pavement   -6.840129
# HLF N 2: Pole       -2.929792
# HLF N 2: SignSymbol  3.033124
# HLF N 3: Building    0.004666
# HLF N 3: Car         0.017435
# HLF N 3: Fence      -0.005221
# HLF N 3: Pavement   -0.081328
# HLF N 3: Pole       -0.062083
# HLF N 3: SignSymbol  0.004710
# HLF N 3: Sky         0.007326
# HLF N 3: Tree        0.014822
# HLF N 4: Bicyclist   0.000000
# HLF N 4: Building    0.000000
# HLF N 4: Car         0.000000
# HLF N 4: Fence       0.000000
# HLF N 4: Pavement    0.000000
# HLF N 4: SignSymbol  0.000000
# HLF N 4: Sky         0.000000
# HLF N 5: Car         0.000000
# HLF N 5: Fence       0.000000
# HLF N 5: Pavement    0.000000

# %%
T[30:58]
# Out:
#                             t-test
# HLF S 1: Building    -3.064339e+00
# HLF S 1: Fence        3.839003e+00
# HLF S 1: Pavement     1.799429e+00
# HLF S 1: Pedestrian   3.485743e+00
# HLF S 1: Pole        -8.904750e+00
# HLF S 1: Road         1.109665e+01
# HLF S 1: SignSymbol   6.899478e-01
# HLF S 1: Tree         1.086074e+01
# HLF S 2: Car          3.258018e+00
# HLF S 2: Fence        6.231902e+00
# HLF S 2: Pavement     3.252165e+00
# HLF S 2: Pole        -7.171958e+00
# HLF S 2: Road         1.106829e+01
# HLF S 2: Tree         9.934158e+00
# HLF S 3: Car          3.224483e-02
# HLF S 3: Pole        -3.629281e-03
# HLF S 3: Road        -1.132245e-02
# HLF S 3: Tree         2.489419e-03
# HLF S 4: Building    1.797693e+308
# HLF S 4: Car         1.797693e+308
# HLF S 4: Fence       1.797693e+308
# HLF S 4: Pavement    1.797693e+308
# HLF S 4: Pole        1.797693e+308
# HLF S 4: Road        1.797693e+308
# HLF S 4: Tree        1.797693e+308
# HLF S 5: Pole        1.797693e+308
# ...

# %%
T[58:71]
# Out:
#                      t-test
# LLF: edges     1.622518e+01
# LLF: mean_h    2.185764e+00
# LLF: mean_l    4.389600e+00
# LLF: mean_s    3.505097e+00
# LLF: stdev_h   7.316574e+00
# LLF: stdev_l   5.624274e+00
# LLF: stdev_s   7.842930e+00
# MU: Beauty    1.797693e+308
# MU: Live       1.579585e+01
# MU: Safety     3.964792e-02
# MU: Wealthy   1.797693e+308
# delta2         7.169413e+01
# tau1          -3.090966e+01

# %%
B
# Out:
#                        Value
# HLF N: Bicyclist    8.065647
# HLF N: Car         -1.584110
# HLF N: Fence        1.851910
# HLF N: Pavement    -3.526712
# HLF N: SignSymbol   1.499843
# HLF N: Sky         -0.835619
# HLF N: Tree         1.086836
# HLF S: Building    -0.901938
# HLF S: Fence        1.667026
# HLF S: Pavement     1.385286
# HLF S: Pole        -2.927657
# HLF S: Road         4.730181
# HLF S: Tree         3.017623
# LAMBDA: car         0.288417
# LAMBDA: person      0.861761
# LLF: edges         12.132418
# LLF: mean_h         0.004800
# LLF: mean_l         0.001018
# LLF: mean_s         0.004602
# LLF: stdev_h        0.014261
# LLF: stdev_l        0.010512
# LLF: stdev_s        0.020313
# MU: Live            0.902610
# OD: bike            0.180024
# OD: car             0.343344
# OD: person          0.064065
# OD: truck          -0.214516
# delta2              0.851108
# tau1               -0.469989
