# %%
import biogeme.results as res
results = res.bioResults(pickleFile ='_Paper-OD.pickle')

# %%
# results

# %%
# dir(results)

# %%
results.getEstimatedParameters().sort_values('Rob. p-value')
# Out:
#                       Value   Std err     t-test       p-value  Rob. Std err  \
# tau1              -0.478457  0.035780 -13.372198  0.000000e+00      0.035895
# delta2             0.916705  0.029530  31.043450  0.000000e+00      0.029510
# HLF S: Tree        1.918621  0.303637   6.318792  2.636158e-10      0.303235
# LLF: edges         8.138164  1.453634   5.598497  2.162176e-08      1.496057
# HLF S: Road        2.356602  0.492901   4.781086  1.743510e-06      0.500125
# HLF N: Sky        -1.294688  0.273373  -4.735982  2.179970e-06      0.276217
# HLF S: Pole       -2.453311  0.595211  -4.121752  3.760015e-05      0.595368
# LLF: stdev_s       0.017778  0.004293   4.140808  3.460853e-05      0.004373
# HLF S: Car         1.108016  0.286596   3.866127  1.105775e-04      0.289742
# HLF N: Pavement   -2.164254  0.574805  -3.765199  1.664166e-04      0.581701
# HLF N: SignSymbol  1.831844  0.487419   3.758250  1.711058e-04      0.496708
# ...
