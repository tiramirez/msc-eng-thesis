# %%
import pandas as pd
import biogeme.database as db
import biogeme.biogeme as bio
import biogeme.distributions as dist
import biogeme.models as models

# %%
biogeme.version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ceff266c816a> in <module>
# ----> 1 biogeme.version
#
# NameError: name 'biogeme' is not defined

# %%
# data = pd.read_csv('./../all_answers.dat',sep='\t', decimal='.')
data = pd.read_csv('./../new_data.dat',sep='\t', decimal='.')

# %%
# data.columns

# %%
data = data[(data['question'] == 1)]

# %%
# age_dummies = pd.get_dummies(pd.cut(data['age_cat'],bins=4,labels=['age_1','age_2','age_3','age_4']))
# data = pd.concat([data,age_dummies],axis=1)

# education_dummies = pd.get_dummies(pd.cut(data['education'],bins=6,labels=['educ_1','educ_2','educ_3','educ_4','educ_5','educ_6']))
# data = pd.concat([data,education_dummies],axis=1)

# transport_dummies = pd.get_dummies(pd.cut(data['transport'],bins=5,labels=['walk','bike','bus','car','other_transport']))
# data = pd.concat([data,transport_dummies],axis=1)

# %%
# norm_df.describe().transpose()

# %%
database = db.Database("database",data)
from headers import *

# %%
# Removing some observations can be done directly using pandas.
#remove = (((database.data.PURPOSE != 1) & (database.data.PURPOSE != 3)) | (database.data.CHOICE == 0))
#database.data.drop(database.data[remove].index,inplace=True)

# Here we use the "biogeme" way for backward compatibility
# exclude = ( (NA_izq != 0) + (NA_der != 0) + \
# 	(outlier_bn_der > 0) + (outlier_hs_der > 0) + (outlier_hlf_der > 1) + \
# 	(outlier_bn_izq > 0) + (outlier_hs_izq > 0) + (outlier_hlf_izq > 1) + \
#     (choice == 99) + (gender == 99)) > 0
# database.remove(exclude)

# %%
A_B_mean_h = Beta('Class A - LLF: mean_h', 0, -100, 100, 0)
A_B_mean_l = Beta('Class A - LLF: mean_l', 0, -100, 100, 0)
A_B_mean_s = Beta('Class A - LLF: mean_s', 0, -100, 100, 0)
A_B_mean_bn = Beta('Class A - LLF: mean_bn', 0, -100, 100, 1)  # NS
A_B_stdev_h = Beta('Class A - LLF: stdev_h', 0, -100, 100, 0)
A_B_stdev_l = Beta('Class A - LLF: stdev_l', 0, -100, 100, 0)
A_B_stdev_s = Beta('Class A - LLF: stdev_s', 0, -100, 100, 0)
A_B_stdev_bn = Beta('Class A - LLF: stdev_bn', 0, -100, 100, 1)  # NS

A_B_edges = Beta('Class A - LLF: edges', 0, -100, 100, 0)
A_B_blobs = Beta('Class A - LLF: blobs', 0, -100, 100, 1)

A_B_Bicyclist_N = Beta('Class A - HLF N: Bicyclist', 0, -100, 100, 1) 
A_B_Building_N = Beta('Class A - HLF N: Building', 0, -100, 100, 0)
A_B_Car_N = Beta('Class A - HLF N: Car', 0, -100, 100, 0) 
A_B_Fence_N = Beta('Class A - HLF N: Fence', 0, -100, 100, 0) 
A_B_Pavement_N = Beta('Class A - HLF N: Pavement', 0, -100, 100, 0)  # NS 0
A_B_Pedestrian_N = Beta('Class A - HLF N: Pedestrian', 0, -100, 100, 0)
A_B_Pole_N = Beta('Class A - HLF N: Pole', 0, -100, 100, 0) 
A_B_Road_N = Beta('Class A - HLF N: Road', 0, -100, 100, 0)  # NS 0
A_B_SignSymbol_N = Beta('Class A - HLF N: SignSymbol', 0, -100, 100, 0) 
A_B_Sky_N = Beta('Class A - HLF N: Sky', 0, -100, 100, 0)
A_B_Tree_N = Beta('Class A - HLF N: Tree', 0, -100, 100, 0)

A_B_Bicyclist_S = Beta('Class A - HLF S: Bicyclist', 0, -100, 100, 1) 
A_B_Building_S = Beta('Class A - HLF S: Building', 0, -100, 100, 0) 
A_B_Car_S = Beta('Class A - HLF S: Car', 0, -100, 100, 0)
A_B_Fence_S = Beta('Class A - HLF S: Fence', 0, -100, 100, 0) 
A_B_Pavement_S = Beta('Class A - HLF S: Pavement', 0, -100, 100, 0)
A_B_Pedestrian_S = Beta('Class A - HLF S: Pedestrian', 0, -100, 100, 0)
A_B_Pole_S = Beta('Class A - HLF S: Pole', 0, -100, 100, 1)
A_B_Road_S = Beta('Class A - HLF S: Road', 0, -100, 100, 0)
A_B_SignSymbol_S = Beta('Class A - HLF S: SignSymbol', 0, -100, 100, 0)
A_B_Sky_S = Beta('Class A - HLF S: Sky', 0, -100, 100, 0) # NS 0 
A_B_Tree_S = Beta('Class A - HLF S: Tree', 0, -100, 100, 0) 

A_D_bench = Beta('Class A - OD: bench', 0, -100, 100, 1)
A_D_boat = Beta('Class A - OD: boat', 0, -100, 100, 1)
A_D_umbrella = Beta('Class A - OD: umbrella', 0, -100, 100, 1)
A_D_chair = Beta('Class A - OD: chair', 0, -100, 100, 0)

A_D_train = Beta('Class A - OD: train', 0, -100, 100, 0)
A_D_potted_plant = Beta('Class A - OD: potted_plant', 0, -100, 100, 1)
A_D_stop_sign = Beta('Class A - OD: stop_sign', 0, -100, 100, 1)
A_D_traffic_light = Beta('Class A - OD: traffic_light', 0, -100, 100, 1)

A_D_bus = Beta('Class A - OD: bus', 0, -100, 100, 1)
A_D_motorcycle = Beta('Class A - OD: motorcycle', 0, -100, 100, 1)
A_D_bike = Beta('Class A - OD: bike BC', 0, -100, 100, 1)

A_D_fire_hydrant = Beta('Class A - OD: fire_hydrant', 0, -100, 100, 0)
A_D_truck = Beta('Class A - OD: truck', 0, -100, 100, 0)

A_D_car_boxcox = Beta('Class A - OD: car BC', 0, -100, 100, 0)
A_LAMBDA_car = Beta('Class A - LAMBDA: car',1.5,0.0001,5,0)

A_D_person_boxcox = Beta('Class A - OD: person BC', 0, -100, 100, 0)
A_LAMBDA_person = Beta('Class A - LAMBDA: person',1.5,0.0001,5,0)

tau1_A	 = Beta('Class A - tau1',-1,None,0,0)
delta2_A	 = Beta('Class A - delta2',2,0,None,0)

tau2_A = tau1_A + delta2_A

# %%
B_mean_h = Beta('Class B - LLF: mean_h', 0, -100, 100, 0)
B_mean_l = Beta('Class B - LLF: mean_l', 0, -100, 100, 0)
B_mean_s = Beta('Class B - LLF: mean_s', 0, -100, 100, 0)
B_mean_bn = Beta('Class B - LLF: mean_bn', 0, -100, 100, 1)  # NS
B_stdev_h = Beta('Class B - LLF: stdev_h', 0, -100, 100, 0)
B_stdev_l = Beta('Class B - LLF: stdev_l', 0, -100, 100, 0)
B_stdev_s = Beta('Class B - LLF: stdev_s', 0, -100, 100, 0)
B_stdev_bn = Beta('Class B - LLF: stdev_bn', 0, -100, 100, 1)  # NS

B_edges = Beta('Class B - LLF: edges', 0, -100, 100, 0)
B_blobs = Beta('Class B - LLF: blobs', 0, -100, 100, 1)


B_Bicyclist_N = Beta('Class B - HLF N: Bicyclist', 0, -100, 100, 1) 
B_Building_N = Beta('Class B - HLF N: Building', 0, -100, 100, 0)
B_Car_N = Beta('Class B - HLF N: Car', 0, -100, 100, 0) 
B_Fence_N = Beta('Class B - HLF N: Fence', 0, -100, 100, 0) 
B_Pavement_N = Beta('Class B - HLF N: Pavement', 0, -100, 100, 0)  # NS 0
B_Pedestrian_N = Beta('Class B - HLF N: Pedestrian', 0, -100, 100, 0)
B_Pole_N = Beta('Class B - HLF N: Pole', 0, -100, 100, 0) 
B_Road_N = Beta('Class B - HLF N: Road', 0, -100, 100, 0)  # NS 0
B_SignSymbol_N = Beta('Class B - HLF N: SignSymbol', 0, -100, 100, 0) 
B_Sky_N = Beta('Class B - HLF N: Sky', 0, -100, 100, 0)
B_Tree_N = Beta('Class B - HLF N: Tree', 0, -100, 100, 0)

B_Bicyclist_S = Beta('Class B - HLF S: Bicyclist', 0, -100, 100, 1) 
B_Building_S = Beta('Class B - HLF S: Building', 0, -100, 100, 0) 
B_Car_S = Beta('Class B - HLF S: Car', 0, -100, 100, 0)
B_Fence_S = Beta('Class B - HLF S: Fence', 0, -100, 100, 0) 
B_Pavement_S = Beta('Class B - HLF S: Pavement', 0, -100, 100, 0)
B_Pedestrian_S = Beta('Class B - HLF S: Pedestrian', 0, -100, 100, 0)
B_Pole_S = Beta('Class B - HLF S: Pole', 0, -100, 100, 1)
B_Road_S = Beta('Class B - HLF S: Road', 0, -100, 100, 0)
B_SignSymbol_S = Beta('Class B - HLF S: SignSymbol', 0, -100, 100, 0)
B_Sky_S = Beta('Class B - HLF S: Sky', 0, -100, 100, 0) # NS 0 
B_Tree_S = Beta('Class B - HLF S: Tree', 0, -100, 100, 0) 


D_bench = Beta('Class B - OD: bench', 0, -100, 100, 1)
D_boat = Beta('Class B - OD: boat', 0, -100, 100, 1)
D_umbrella = Beta('Class B - OD: umbrella', 0, -100, 100, 1)
D_chair = Beta('Class B - OD: chair', 0, -100, 100, 0)

D_train = Beta('Class B - OD: train', 0, -100, 100, 0)
D_potted_plant = Beta('Class B - OD: potted_plant', 0, -100, 100, 1)
D_stop_sign = Beta('Class B - OD: stop_sign', 0, -100, 100, 1)
D_traffic_light = Beta('Class B - OD: traffic_light', 0, -100, 100, 1)

D_bus = Beta('Class B - OD: bus', 0, -100, 100, 1)
D_motorcycle = Beta('Class B - OD: motorcycle', 0, -100, 100, 1)
D_bike = Beta('Class B - OD: bike BC', 0, -100, 100, 1)

# D_person = Beta('Class B - OD: person', 0, -100, 100, 1)
# D_car = Beta('Class B - OD: car', 0, -100, 100, 1)

D_fire_hydrant = Beta('Class B - OD: fire_hydrant', 0, -100, 100, 0)
D_truck = Beta('Class B - OD: truck', 0, -100, 100, 0)

D_car_boxcox = Beta('Class B - OD: car BC', 0, -100, 100, 0)
LAMBDA_car = Beta('Class B - LAMBDA: car',1.5,0.0001,5,0)

D_person_boxcox = Beta('Class B - OD: person BC', 0, -100, 100, 0)
LAMBDA_person = Beta('Class B - LAMBDA: person',1.5,0.0001,5,1)

# D_car_01 = Beta('Class B - OD: car 1', 0, -100, 100, 0)
# D_car_02 = Beta('Class B - OD: car 2', 0, -100, 100, 0)
# D_car_03 = Beta('Class B - OD: car 3', 0, -100, 100, 0)
# D_car_04 = Beta('Class B - OD: car 4', 0, -100, 100, 0)
# D_car_05 = Beta('Class B - OD: car 5', 0, -100, 100, 0)
# D_car_06 = Beta('Class B - OD: car 6-20', 0, -100, 100, 0)


tau1_B	 = Beta('Class B - tau1',-1,None,0,0)
delta2_B	 = Beta('Class B - delta2',2,0,None,0)

tau2_B = tau1_B + delta2_B

# %%
UA =  A_B_mean_h * mean_h + \
     A_B_mean_l * mean_l + \
     A_B_mean_s * mean_s + \
     A_B_mean_bn * mean_bn + \
     A_B_stdev_h * stdev_h + \
     A_B_stdev_l * stdev_l + \
     A_B_stdev_s * stdev_s + \
     A_B_stdev_bn * stdev_bn + \
     A_B_edges * edges + \
     A_B_blobs * blobs + \
     A_B_Bicyclist_N * N_Bicyclist + \
     A_B_Building_N * N_Building + \
     A_B_Car_N * N_Car + \
     A_B_Fence_N * N_Fence + \
     A_B_Pavement_N * N_Pavement + \
     A_B_Pedestrian_N * N_Pedestrian + \
     A_B_Pole_N * N_Pole + \
     A_B_Road_N * N_Road + \
     A_B_SignSymbol_N * N_SignSymbol + \
     A_B_Sky_N * N_Sky + \
     A_B_Tree_N * N_Tree + \
     A_B_Bicyclist_S * S_Bicyclist + \
     A_B_Building_S * S_Building + \
     A_B_Car_S * S_Car + \
     A_B_Fence_S * S_Fence + \
     A_B_Pavement_S * S_Pavement + \
     A_B_Pedestrian_S * S_Pedestrian + \
     A_B_Pole_S * S_Pole + \
     A_B_Road_S * S_Road + \
     A_B_SignSymbol_S * S_SignSymbol + \
     A_B_Sky_S * S_Sky + \
     A_B_Tree_S * S_Tree + \
     A_D_bench * OD_bench + \
     A_D_chair * OD_chair + \
     A_D_fire_hydrant * OD_fire_hydrant + \
     A_D_potted_plant * OD_potted_plant + \
     A_D_stop_sign * OD_stop_sign + \
     A_D_traffic_light * OD_traffic_light + \
     A_D_train * OD_train + \
     A_D_umbrella * OD_umbrella + \
     A_D_car_boxcox * models.boxcox(OD_car_izq,LAMBDA_car) - \
     A_D_car_boxcox * models.boxcox(OD_car_der,LAMBDA_car ) + \
     A_D_person_boxcox * models.boxcox(OD_person_izq,LAMBDA_person) - \
     A_D_person_boxcox * models.boxcox(OD_person_der,LAMBDA_person) + \
     A_D_truck * (OD_truck_izq - OD_truck_der)


UB = B_mean_h * mean_h + \
     B_mean_l * mean_l + \
     B_mean_s * mean_s + \
     B_mean_bn * mean_bn + \
     B_stdev_h * stdev_h + \
     B_stdev_l * stdev_l + \
     B_stdev_s * stdev_s + \
     B_stdev_bn * stdev_bn + \
     B_edges * edges + \
     B_blobs * blobs + \
     B_Bicyclist_N * N_Bicyclist + \
     B_Building_N * N_Building + \
     B_Car_N * N_Car + \
     B_Fence_N * N_Fence + \
     B_Pavement_N * N_Pavement + \
     B_Pedestrian_N * N_Pedestrian + \
     B_Pole_N * N_Pole + \
     B_Road_N * N_Road + \
     B_SignSymbol_N * N_SignSymbol + \
     B_Sky_N * N_Sky + \
     B_Tree_N * N_Tree + \
     B_Bicyclist_S * S_Bicyclist + \
     B_Building_S * S_Building + \
     B_Car_S * S_Car + \
     B_Fence_S * S_Fence + \
     B_Pavement_S * S_Pavement + \
     B_Pedestrian_S * S_Pedestrian + \
     B_Pole_S * S_Pole + \
     B_Road_S * S_Road + \
     B_SignSymbol_S * S_SignSymbol + \
     B_Sky_S * S_Sky + \
     B_Tree_S * S_Tree + \
     D_bench * OD_bench + \
     D_chair * OD_chair + \
     D_fire_hydrant * OD_fire_hydrant + \
     D_potted_plant * OD_potted_plant + \
     D_stop_sign * OD_stop_sign + \
     D_traffic_light * OD_traffic_light + \
     D_train * OD_train + \
     D_umbrella * OD_umbrella + \
     D_car_boxcox * models.boxcox(OD_car_izq,LAMBDA_car) - \
     D_car_boxcox * models.boxcox(OD_car_der,LAMBDA_car ) + \
     D_person_boxcox * models.boxcox(OD_person_izq,LAMBDA_person) - \
     D_person_boxcox * models.boxcox(OD_person_der,LAMBDA_person) + \
     D_truck * (OD_truck_izq - OD_truck_der)

# %%
C_Cte = Beta('Class: Constant', 0.3, -100, 100, 0)
C_Gender = Beta('Class: Female', -0.5, -100, 100, 0) 
C_Walk = Beta('Class: Walk', 0, -100, 100, 1) 
C_Car = Beta('Class: Car', 0, -100, 100, 1) 
C_Age = Beta('Class: Age', 0, -100, 100, 1) 

utilClassA = C_Cte + \
            C_Gender * gender + \
            C_Age * age 

#             C_Walk * walk + \
#             C_Car * car

probClassA = exp(utilClassA) / (1 + exp(utilClassA))
probClassB = 1 - probClassA

# %%
ChoiceProba_A = {
    1: 1-dist.logisticcdf(UA-tau1_A),
    3: dist.logisticcdf(UA-tau1_A)- dist.logisticcdf(UA-tau2_A),
    2: dist.logisticcdf(UA-tau2_A) }

logprob_A = log(Elem(ChoiceProba_A,choice))

ChoiceProba_B = {
    1: 1-dist.logisticcdf(UB-tau1_B),
    3: dist.logisticcdf(UB-tau1_B)- dist.logisticcdf(UB-tau2_B),
    2: dist.logisticcdf(UB-tau2_B) }

logprob_B = log(Elem(ChoiceProba_B,choice))

probChoice = probClassA * logprob_A + probClassB * logprob_B

# %%
biogeme = bio.BIOGEME(database,probChoice,numberOfThreads=4)
biogeme.modelName = "walk_01"
results = biogeme.estimate(algorithm=None)
# print("Results=",results)
R = results.getEstimatedParameters()

B = pd.DataFrame(R['Value'])
T = pd.DataFrame(R['t-test'])

# B = B.merge(R['Value'],how='left',left_index=True,right_index=True)
# T = T.merge(R['t-test'],how='left',left_index=True,right_index=True)

# T = pd.concat([T,R['t-test']],axis=1, sort=False)
# B = pd.concat([B,R['Value']],axis=1, sort=False)

# %%
R
# Out:
#                                  Value        Std err         t-test  p-value  \
# Class A - HLF N: Building    26.744612  1.797693e+308  1.487718e-307      1.0
# Class A - HLF N: Car         29.680945  1.797693e+308  1.651057e-307      1.0
# Class A - HLF N: Fence       26.115860  1.797693e+308  1.452743e-307      1.0
# Class A - HLF N: Pavement    32.318100  1.797693e+308  1.797754e-307      1.0
# Class A - HLF N: Pedestrian  23.076556  1.797693e+308  1.283676e-307      1.0
# ...                                ...            ...            ...      ...
# Class B - OD: truck          -0.164271  1.797693e+308 -9.137897e-310      1.0
# Class B - delta2              0.637766  1.797693e+308  3.547692e-309      1.0
# Class B - tau1               -0.194837  1.797693e+308 -1.083815e-309      1.0
# Class: Constant              11.654404   0.000000e+00  1.797693e+308      0.0
# Class: Female                 4.187524   0.000000e+00  1.797693e+308      0.0
#
# ...

# %%
R

# %%
T
# Out:
#                                     t-test
# Class A - HLF N: Building    1.487718e-307
# Class A - HLF N: Car         1.651057e-307
# Class A - HLF N: Fence       1.452743e-307
# Class A - HLF N: Pavement    1.797754e-307
# Class A - HLF N: Pedestrian  1.283676e-307
# ...                                    ...
# Class B - OD: truck         -9.137897e-310
# Class B - delta2             3.547692e-309
# Class B - tau1              -1.083815e-309
# Class: Constant              1.797693e+308
# Class: Female                1.797693e+308
#
# [72 rows x 1 columns]

# %%
B

# %%
# T.to_csv('test_t.csv')
# B.to_csv('betas.csv')

# %%
# results.getBetaValues()

# %%
# help(results)

# %%
# var = data['Tree_N']
# var.plot.hist(bins=50)
